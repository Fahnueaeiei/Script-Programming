# %%
# Activity 2.2: Choose Your Own Adventure
# เรื่อง: หลงเข้าไปในป่าลึกลับ
#
# บทนำ: คุณตื่นขึ้นมากลางป่า พบทางแยก 2 ทาง

# จุดตัดสินใจที่ 1:
# choice1 = input("เลือกทาง: ซ้าย(มืด) หรือ ขวา(มีแสง)? ")
#
# if choice1 == "ซ้าย":
#     -> เจอถ้ำ มีสมบัติซ่อนอยู่ แต่เสี่ยงเจอสัตว์ป่า
# elif choice1 == "ขวา":
#     -> เจอทะเลสาบ สงบ ปลอดภัยกว่า แต่ไม่มีของรางวัล


# จุดตัดสินใจที่ 2 (ถ้าเลือกถ้ำ):
# answer2 = input("จะหยิบสมบัติไหม? yes/no ")
#
# if answer2 == "yes":
#     -> สัตว์ป่าโผล่มา ต้องวิ่งหนี (จบแบบเสี่ยงตาย)
# elif answer2 == "no":
#     -> เดินออกจากถ้ำอย่างปลอดภัย (จบแบบธรรมดา)


# จุดตัดสินใจที่ 3 (ถ้าเลือกทะเลสาบ):
# answer3 = input("จะว่ายน้ำข้ามไปฝั่งตรงข้ามไหม? yes/no ")
#
# if answer3 == "yes":
#     -> เจอทางออกจากป่า (Happy Ending)
# elif answer3 == "no":
#     -> ต้องนอนพักในป่าอีกคืน (จบค้างเรื่อง)
